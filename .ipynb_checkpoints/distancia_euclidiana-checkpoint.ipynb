# %%
import pandas as pd
from scipy.spatial import distance
from sklearn import preprocessing

# %%
# Reading Sample Table
df = pd.read_csv("./db/cidades_metrics.csv",
                 sep=",",
                 encoding="utf-8-sig",
                 low_memory=False,
                 index_col="key")

# %%
df.fillna(0, inplace=True)

# %%
# Normalizing Values (0 to 1
df = pd.DataFrame(preprocessing.MinMaxScaler().fit_transform(df.values),
                  columns=df.columns,
                  index=df.index)

# %%
# Calculating Euclidian Distance Between Cities
ed = pd.DataFrame(data=distance.cdist(df.values, df.values),
                  columns=list(df.index),
                  index=df.index)

# %%
# Nominal 5 Closest Cities
auxl = []
for col in ed.columns:
    auxl.append({'City': col,
                 '1st_close': ed[col].sort_values().index[1],
                 '2st_close': ed[col].sort_values().index[2],
                 '3st_close': ed[col].sort_values().index[3],
                 '4st_close': ed[col].sort_values().index[4],
                 '5st_close': ed[col].sort_values().index[5],
                 })

lf = pd.DataFrame.from_dict(auxl)
lf.set_index('City', inplace=True)

# %%
ed.head()
# Out:
#                acreuna-GO  adamantina-SP  agudos-SP  alexania-GO  alfenas-MG  \
# key
# acreuna-GO       0.000000       1.385910   1.511772     1.419515    0.577883
# adamantina-SP    1.385910       0.000000   0.668081     1.889527    1.151391
# agudos-SP        1.511772       0.668081   0.000000     1.862649    1.110139
# alexania-GO      1.419515       1.889527   1.862649     0.000000    1.522087
# alfenas-MG       0.577883       1.151391   1.110139     1.522087    0.000000
#
#                altamira-PA  americana-SP  amparo-SP  ampere-PR  anapolis-GO  \
# key
# acreuna-GO        0.751050      1.378569   1.718060   0.896041     0.510133
# adamantina-SP     1.490251      0.397226   1.212147   1.338777     1.317642
# agudos-SP         1.391619      0.394922   1.354691   1.762190     1.331863
# alexania-GO       1.549326      1.853412   2.005614   1.874538     1.351448
# alfenas-MG        0.455610      1.068403   1.649787   1.128413     0.394791
#
# ...

# %%
lf.head()
# Out:
#                       1st_close               2st_close  \
# City
# acreuna-GO             mafra-SC     sao bento do sul-SC
# adamantina-SP        birigui-SP  presidente prudente-SP
# agudos-SP        hortolandia-SP               sumare-SP
# alexania-GO         pomerode-SC               itapoa-SC
# alfenas-MG     tres coracoes-MG              palhoca-SC
#
#                               3st_close              4st_close  \
# City
# acreuna-GO                   guaxupe-MG         pato branco-PR
# adamantina-SP  sao jose do rio preto-SP           ituverava-SP
# agudos-SP                    marilia-SP         pederneiras-SP
# alexania-GO       dionisio cerqueira-SC  primavera do leste-MT
# alfenas-MG             novo hamburgo-RS               cambe-PR
#
#                      5st_close
# City
# acreuna-GO            xaxim-SC
# adamantina-SP     bebedouro-SP
# agudos-SP        mogi guacu-SP
# alexania-GO         aracruz-ES
# alfenas-MG     pouso alegre-MG

# %%
lf.loc['sao paulo-SP']
# Out:
# 1st_close         rio de janeiro-RJ
# 2st_close               campinas-SP
# 3st_close    sao jose dos campos-SP
# 4st_close              guarulhos-SP
# 5st_close         ribeirao preto-SP
# Name: sao paulo-SP, dtype: object

# %%
import pandas as pd
import numpy as np

# %%
from scipy.spatial import distance
from sklearn import preprocessing

# %%
df = pd.read_csv("cidades_metrics.csv", sep=",", encoding="utf-8-sig", low_memory=False, index_col="key")

# %%
df.fillna(0, inplace=True)

# %%
x = df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled, columns=df.columns, index=df.index)

# %%
df.head()
# Out:
#                    area  populacao  pib_per_capita  total_uf  cidade_pct  \
# key
# acreuna-GO     0.004085   0.000960        0.032111  0.114136    0.001010
# adamantina-SP  0.006573   0.002040        0.031140  1.000000    0.002728
# agudos-SP      0.009440   0.002184        0.161915  1.000000    0.001717
# alexania-GO    0.011995   0.001348        0.047228  0.114136    0.000303
# alfenas-MG     0.022491   0.005725        0.032465  0.276702    0.005657
#
#                  uf_pct  camaro    cobalt     cruze  cruze_sport6   montana  \
# key
# acreuna-GO     0.114136     0.0  0.000000  0.300000      0.250000  0.300000
# adamantina-SP  1.000000     0.0  0.222222  0.111111      0.277778  0.000000
# agudos-SP      1.000000     0.0  0.176471  0.352941      0.000000  0.000000
# alexania-GO    0.114136     0.0  1.000000  1.000000      0.000000  0.000000
# alfenas-MG     0.276702     0.0  0.000000  0.267857      0.133929  0.214286
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417 entries, acreuna-GO to xaxim-SC
# Data columns (total 17 columns):
# area              417 non-null float64
# populacao         417 non-null float64
# pib_per_capita    417 non-null float64
# total_uf          417 non-null float64
# cidade_pct        417 non-null float64
# uf_pct            417 non-null float64
# camaro            417 non-null float64
# cobalt            417 non-null float64
# cruze             417 non-null float64
# cruze_sport6      417 non-null float64
# montana           417 non-null float64
# onix              417 non-null float64
# prisma            417 non-null float64
# s10               417 non-null float64
# spin              417 non-null float64
# tracker           417 non-null float64
# trailblazer       417 non-null float64
# dtypes: float64(17)
# memory usage: 58.6+ KB

# %%
# Feedbadk
ed = pd.read_csv("euclidian_matrix_br_cities.csv", index_col='city_idx')

# %%
ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417 entries, acreuna-GO to sao paulo-SP
# Columns: 417 entries, acreuna-GO to xaxim-SC
# dtypes: float64(417)
# memory usage: 1.3+ MB

# %%
ed.head()
# Out:
#                      acreuna-GO  adamantina-SP  agudos-SP  alexania-GO  \
# city_idx
# acreuna-GO             0.000000       1.385910   1.511521     1.419512
# mafra-SC               0.382406       1.227473   1.308659     1.206167
# sao bento do sul-SC    0.382566       1.161510   1.245830     1.450670
# guaxupe-MG             0.403968       1.139863   1.186433     1.266947
# pato branco-PR         0.405041       1.118719   1.207509     1.347052
#
#                      alfenas-MG  altamira-PA  americana-SP  amparo-SP  \
# city_idx
# acreuna-GO             0.577883     0.751023      1.378421   1.717920
# mafra-SC               0.498102     0.767703      1.184887   1.638569
# sao bento do sul-SC    0.347184     0.567861      1.135595   1.614356
# guaxupe-MG             0.379933     0.677801      1.093505   1.588702
# pato branco-PR         0.379999     0.688871      1.092900   1.586865
#
#                      ampere-PR  anapolis-GO  ...  vila velha-ES  vilhena-RO  \
# ...

# %%
ed.sort_index(inplace=True, ascending=True)

# %%
ed.sort_index(axis=1, inplace=True, ascending=True)

# %%
ed.head()
# Out:
#                acreuna-GO  adamantina-SP  agudos-SP  alexania-GO  alfenas-MG  \
# city_idx
# acreuna-GO       0.000000       1.385910   1.511521     1.419512    0.577883
# adamantina-SP    1.385910       0.000000   0.667504     1.889524    1.151391
# agudos-SP        1.511521       0.667504   0.000000     1.862490    1.109799
# alexania-GO      1.419512       1.889524   1.862490     0.000000    1.522084
# alfenas-MG       0.577883       1.151391   1.109799     1.522084    0.000000
#
#                altamira-PA  americana-SP  amparo-SP  ampere-PR  anapolis-GO  \
# city_idx
# acreuna-GO        0.751023      1.378421   1.717920   0.896041     0.510024
# adamantina-SP     1.490236      0.396702   1.211946   1.338777     1.317598
# agudos-SP         1.391458      0.394853   1.354679   1.761975     1.331754
# alexania-GO       1.549323      1.853334   2.005527   1.874535     1.351428
# alfenas-MG        0.455567      1.068213   1.649643   1.128413     0.394652
#
# ...

# %%
fed = pd.DataFrame(data=distance.cdist(df.values, df.values), 
                   columns=list(df.index), index=df.index)

# %%
fed.head()
# Out:
#                acreuna-GO  adamantina-SP  agudos-SP  alexania-GO  alfenas-MG  \
# key
# acreuna-GO       0.000000       1.385910   1.511521     1.419512    0.577883
# adamantina-SP    1.385910       0.000000   0.667504     1.889524    1.151391
# agudos-SP        1.511521       0.667504   0.000000     1.862490    1.109799
# alexania-GO      1.419512       1.889524   1.862490     0.000000    1.522084
# alfenas-MG       0.577883       1.151391   1.109799     1.522084    0.000000
#
#                altamira-PA  americana-SP  amparo-SP  ampere-PR  anapolis-GO  \
# key
# acreuna-GO        0.751023      1.378421   1.717920   0.896041     0.510024
# adamantina-SP     1.490236      0.396702   1.211946   1.338777     1.317598
# agudos-SP         1.391458      0.394853   1.354679   1.761975     1.331754
# alexania-GO       1.549323      1.853334   2.005527   1.874535     1.351428
# alfenas-MG        0.455567      1.068213   1.649643   1.128413     0.394652
#
# ...

# %%
fed.sort_index(inplace=True, ascending=True)
fed.sort_index(axis=1, inplace=True, ascending=True)

# %%
fed.equals(ed)
# Out:
# False

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(fed, cmap='viridis',annot=False, ax=ax)
plt.show()

# %%
distance.cdist(df.values, df.values).shape

# %%
results = {}
lenght = len(ndf.columns)
ctr = 1
for state in ndf.columns:
    for aux_state in ndf.columns:
        x = distance.euclidean(ndf['{0}'.format(state)].values, ndf['{0}'.format(aux_state)].values)
        print("Loading - {3} % \t|\t Distance between {0} - {1} = {2} ".format(state, 
                                                                             aux_state, 
                                                                             x, 
                                                                             (100*np.round(ctr/(lenght**2)))), 
              end='\r', flush=True)
        results.update({(state, aux_state): x})
        ctr += 1

# %%
results

# %%
final_frame = pd.DataFrame.from_dict(results, orient='index')

# %%
final_frame.head()

# %%
final_frame.info()

# %%
final_frame.reset_index(inplace=True)

# %%
final_frame.rename({'index': 'aux', 0: 'values'}, axis=1, inplace=True)

# %%
final_frame['city_col'] = final_frame.aux.apply(lambda x: x[0])
final_frame['city_idx'] = final_frame.aux.apply(lambda x: x[1])

# %%
final_frame.drop('aux', axis=1, inplace=True)

# %%
md = final_frame.pivot_table(values='values', index='city_idx', columns='city_col')

# %%
md.sort_values(list(md.columns), inplace=True)

# %%
md.head()

# %%
md.to_csv("euclidian_matrix_br_cities.csv", sep=",", encoding="utf-8-sig")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
md['sao paulo-SP'].sort_values()[1:5]

# %%
auxl = []
for col in ed.columns:
    auxl.append({'City': col, 
                 '1st_close': ed['{0}'.format(col)].sort_values().index[1],
                 '2st_close': ed['{0}'.format(col)].sort_values().index[2],
                 '3st_close': ed['{0}'.format(col)].sort_values().index[3],
                 '4st_close': ed['{0}'.format(col)].sort_values().index[4],
                })

# %%
df = pd.DataFrame.from_dict(auxl)

# %%
df.set_index('City', inplace=True)

# %%
df.head()
# Out:
#                       1st_close               2st_close  \
# City
# acreuna-GO             mafra-SC     sao bento do sul-SC
# adamantina-SP        birigui-SP  presidente prudente-SP
# agudos-SP        hortolandia-SP               sumare-SP
# alexania-GO         pomerode-SC               itapoa-SC
# alfenas-MG     tres coracoes-MG              palhoca-SC
#
#                               3st_close              4st_close
# City
# acreuna-GO                   guaxupe-MG         pato branco-PR
# adamantina-SP  sao jose do rio preto-SP           ituverava-SP
# agudos-SP                    marilia-SP         pederneiras-SP
# alexania-GO       dionisio cerqueira-SC  primavera do leste-MT
# alfenas-MG             novo hamburgo-RS               cambe-PR

# %%
df.to_csv("closest_ed_cities.csv", sep=",", encoding="utf-8-sig")
